# %% [markdown]
# <a href="https://www.kaggle.com/code/neesham/seaborn-for-beginners?scriptVersionId=92634778" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# > Beautiful code is short and concise, so if you were to give that code to another programmer they would say, "oh, that's well written code." It's much like as if you were writing a poem.
#
#    *- It is a coding prodigy **Santiago Gonzalez** quote.*

# %% [markdown]
# ## Well, Seaborn gives us the power to write short and concise code which anyone can understand.
#
# ## Ready? Let's get your feet wet!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import chardet
import os
from warnings import simplefilter

simplefilter("ignore")

# %% [markdown]
# ### Loading the datasets.

# %%
super_store_data = pd.read_csv("../input/superstore-dataset-final/Sample - Superstore.csv", encoding = 'ISO-8859-1')
human_resources_data = pd.read_csv("../input/human-resources-data-set/HRDataset_v14.csv")

print(super_store_data.columns)
print(human_resources_data.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
super_store_data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
human_resources_data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# ## 1. Relationship plots
#
# ### 1. lineplot

# %%
# Use this line to change the widht and height of the seaborn plot.
plt.figure(figsize = (10, 6))

# Display pixel per inch, imporves the visibility of the plot.
plt.figure(dpi = 150)

# Set the title of the plot.
plt.title("Relationship between EngagementSurvey and Salary")

sns.lineplot(x = "EngagementSurvey", y = "Salary", data = human_resources_data)
# Out:
# <AxesSubplot:title={'center':'Relationship between EngagementSurvey and Salary'}, xlabel='EngagementSurvey', ylabel='Salary'>

# %% [markdown]
# #### Some examples of lineplot.

# %%
plt.figure(figsize = (10, 6), dpi = 150)
plt.title("Relationship between SpecialProjjectsCount and Salary")
sns.lineplot(x = "SpecialProjectsCount", y = "Salary", data = human_resources_data)
# Out:
# <AxesSubplot:title={'center':'Relationship between SpecialProjjectsCount and Salary'}, xlabel='SpecialProjectsCount', ylabel='Salary'>

# %%
plt.title("lineplot without using any customization.")
sns.lineplot(x = "EmpSatisfaction", y = "Salary", data = human_resources_data)
# Out:
# <AxesSubplot:title={'center':'lineplot without using any customization.'}, xlabel='EmpSatisfaction', ylabel='Salary'>

# %% [markdown]
# ### 2. scatterplot

# %%
# Use this line to change the widht and height of the seaborn plot.
plt.figure(figsize = (10, 6))

# Display pixel per inch, imporves the visibility of the plot.
plt.figure(dpi = 150)

# Set the title of the plot.
plt.title("Relationship between EngagementSurvey and Salary")

sns.scatterplot(x = "DaysLateLast30", y = "Salary", data = human_resources_data)
# Out:
# <AxesSubplot:title={'center':'Relationship between EngagementSurvey and Salary'}, xlabel='DaysLateLast30', ylabel='Salary'>

# %% [markdown]
# #### Some examples of scatterplot

# %%
plt.figure(figsize = (10, 6), dpi = 150)

# custom color template for the plot.
color = sns.color_palette("bright")
sns.set_palette(color)

sns.scatterplot(x = "Category", y = "Sales", data = super_store_data)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %% [markdown]
# ### color palettes

# %%
current_palette = sns.color_palette("Purples_r")
sns.palplot(current_palette)
plt.show()

# %% [markdown]
# ### These are the possible values of the palettes.
#
# ‘Accent’, ‘Accent_r’, ‘Blues’, ‘Blues_r’, ‘BrBG’, ‘BrBG_r’, ‘BuGn’, ‘BuGn_r’, ‘BuPu’, ‘BuPu_r’, ‘CMRmap’, ‘CMRmap_r’, ‘Dark2’, ‘Dark2_r’, ‘GnBu’, ‘GnBu_r’,  ‘Greens’, ‘Greens_r’, ‘Greys’, ‘Greys_r’, ‘OrRd’, ‘OrRd_r’, ‘Oranges’, ‘Oranges_r’,  ‘PRGn’, ‘PRGn_r’, ‘Paired’, ‘Paired_r’, ‘Pastel1’, ‘Pastel1_r’, ‘Pastel2’,  ‘Pastel2_r’, ‘PiYG’, ‘PiYG_r’, ‘PuBu’, ‘PuBuGn’, ‘PuBuGn_r’, ‘PuBu_r’, ‘PuOr’, ‘PuOr_r’, ‘PuRd’, ‘PuRd_r’, ‘Purples’, ‘Purples_r’, ‘RdBu’, ‘RdBu_r’, ‘RdGy’, ‘RdGy_r’, ‘RdPu’, ‘RdPu_r’, ‘RdYlBu’, ‘RdYlBu_r’, ‘RdYlGn’, ‘RdYlGn_r’, ‘Reds’, ‘Reds_r’, ‘Set1’, ‘Set1_r’, ‘Set2’, ‘Set2_r’, ‘Set3’, ‘Set3_r’, ‘Spectral’, ‘Spectral_r’, ‘Wistia’, ‘Wistia_r’, ‘YlGn’, ‘YlGnBu’, ‘YlGnBu_r’, ‘YlGn_r’, ‘YlOrBr’, ‘YlOrBr_r’, ‘YlOrRd’, ‘YlOrRd_r’, ‘afmhot’, ‘afmhot_r’, ‘autumn’, ‘autumn_r’, ‘binary’, ‘binary_r’,  ‘bone’, ‘bone_r’, ‘brg’, ‘brg_r’, ‘bwr’, ‘bwr_r’, ‘cividis’, ‘cividis_r’, ‘cool’, ‘cool_r’,  ‘coolwarm’, ‘coolwarm_r’, ‘copper’, ‘copper_r’, ‘cubehelix’, ‘cubehelix_r’, ‘flag’, ‘flag_r’,  ‘gist_earth’, ‘gist_earth_r’, ‘gist_gray’, ‘gist_gray_r’, ‘gist_heat’, ‘gist_heat_r’, ‘gist_ncar’,  ‘gist_ncar_r’, ‘gist_rainbow’, ‘gist_rainbow_r’, ‘gist_stern’, ‘gist_stern_r’, ‘gist_yarg’,  ‘gist_yarg_r’, ‘gnuplot’, ‘gnuplot2’, ‘gnuplot2_r’, ‘gnuplot_r’, ‘gray’, ‘gray_r’, ‘hot’, ‘hot_r’,  ‘hsv’, ‘hsv_r’, ‘icefire’, ‘icefire_r’, ‘inferno’, ‘inferno_r’, ‘jet’, ‘jet_r’, ‘magma’, ‘magma_r’,  ‘mako’, ‘mako_r’, ‘nipy_spectral’, ‘nipy_spectral_r’, ‘ocean’, ‘ocean_r’, ‘pink’, ‘pink_r’,  ‘plasma’, ‘plasma_r’, ‘prism’, ‘prism_r’, ‘rainbow’, ‘rainbow_r’, ‘rocket’, ‘rocket_r’,  ‘seismic’, ‘seismic_r’, ‘spring’, ‘spring_r’, ‘summer’, ‘summer_r’, ‘tab10’, ‘tab10_r’,’tab20′, ‘tab20_r’, ‘tab20b’, ‘tab20b_r’, ‘tab20c’, ‘tab20c_r’, ‘terrain’, ‘terrain_r’, ‘turbo’,  ‘turbo_r’, ‘twilight’, ‘twilight_r’, ‘twilight_shifted’, ‘twilight_shifted_r’, ‘viridis’,  ‘viridis_r’, ‘vlag’, ‘vlag_r’, ‘winter’, ‘winter_r’

# %% [markdown]
# ## 2. Categorical plots

# %% [markdown]
# ### 1. countplot

# %%
plt.figure(figsize = (18, 6))

# Set the title of the plot.
plt.title("Number of Employees hired from each Platforms.")

sns.countplot(x = "RecruitmentSource", data = human_resources_data)
# Out:
# <AxesSubplot:title={'center':'Number of Employees hired from each Platforms.'}, xlabel='RecruitmentSource', ylabel='count'>

# %% [markdown]
# #### Some examples of countplot

# %%
plt.figure(figsize = (8, 4), dpi = 150)

# setting the different color palette
color_palette = sns.color_palette("plasma")
sns.set_palette(color_palette)

sns.countplot(x = human_resources_data["PerformanceScore"], data = human_resources_data)
# Out:
# <AxesSubplot:xlabel='PerformanceScore', ylabel='count'>

# %%
plt.figure(figsize = (8, 4), dpi = 150)

sns.countplot(x = human_resources_data["MarriedID"], data = human_resources_data)
# Out:
# <AxesSubplot:xlabel='MarriedID', ylabel='count'>

# %% [markdown]
# ### 2. boxplot

# %%
plt.figure(figsize = (10, 6), dpi = 100)
sns.boxplot(x = "Category", y = "Sales",  data = super_store_data)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %% [markdown]
# ### 3. violinplot

# %%
plt.figure(figsize = (10, 6), dpi = 100)

# setting the different color palette
color_palette = sns.color_palette("Accent_r")
sns.set_palette(color_palette)

sns.violinplot(x = "Category", y = "Sales",  data = super_store_data)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %% [markdown]
# ### Pro tip:
# You can use sns.catplot() it provides a kind perameter in which you can specify the type of plot you want. Possible values are, violin, box, bar, count, swarm.

# %% [markdown]
# #### Some examples of catplot examples

# %%
plt.figure(figsize = (10, 6), dpi = 100)
sns.catplot(x = "Category", y = "Sales",  data = super_store_data, kind = "violin")

# %%
plt.figure(figsize = (10, 6), dpi = 100)
sns.catplot(x = "Category", y = "Sales",  data = super_store_data, kind = "bar")

# %% [markdown]
# ## 3. Distribution plots
#
# ### 1. displot

# %%
plt.figure(figsize = (10, 6), dpi = 200)
sns.displot(np.log1p(super_store_data['Sales']))

# %% [markdown]
# ### 2. kdeplot

# %%
plt.figure(figsize = (10, 6), dpi = 150)
sns.kdeplot(data = super_store_data, x = "Sales", shade = True)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
plt.figure(figsize = (10, 6), dpi = 150)
sns.kdeplot(data = super_store_data, x = "Profit",shade = True)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %% [markdown]
# ## 4. Matrix plots

# %%
plt.figure(figsize = (10, 6), dpi = 150)

# setting the color palette
color = sns.color_palette("BuGn_r")
sns.set_palette(color)

corr_matrix = super_store_data.corr()

plt.figure(figsize = (10, 5))
sns.heatmap(corr_matrix, vmax=0.9, annot=True, cmap=color)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Thanks for reading this notebook.
# ### Checkout my other notebooks 🙃
# * [Deep Neural Network V/S XGBoost](https://www.kaggle.com/code/neesham/deep-neural-network-v-s-xgboost)
# * [EDA - Google Play Store](https://www.kaggle.com/code/neesham/eda-google-play-store)
